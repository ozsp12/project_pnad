# %% [markdown]
# # PNAD metadata
#
# This notebook is a minimal manual entry point for the metadata pipeline implemented in `src/build_metadata.py`.

# %%
from pathlib import Path
import sys

cwd = Path.cwd().resolve()
for candidate in (cwd, *cwd.parents):
    if (candidate / 'src' / 'build_metadata.py').exists():
        project_root = candidate
        break
else:
    raise FileNotFoundError('Could not locate project root containing src/build_metadata.py')

src_dir = project_root / 'src'
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

from build_metadata import main

df_metadata, output_path = main()
print(f'df_metadata saved to: {output_path}')
df_metadata
# Out:
# df_metadata saved to: C:\Users\Osvaldo\OneDrive\github_oz\project_pnad\data\metadata\df_metadata.xlsx
#      ano var_renda  pos_renda  tam_renda var_morador  pos_morador  \
# 0   1976     V2954      227.0        9.0         NaN          NaN
# 1   1977      V131      288.0        9.0         NaN          NaN
# 2   1978     V2541      214.0        9.0         NaN          NaN
# 3   1979     V2517      167.0        9.0         NaN          NaN
# 4   1980       NaN        NaN        NaN         NaN          NaN
# 5   1981     V5010      223.0        7.0       V9329        219.0
# 6   1982      V602      199.0        7.0         NaN          NaN
# 7   1983     V5010      223.0        7.0       V9329        219.0
# 8   1984     V5010      223.0        7.0       V9329        219.0
# 9   1985     V5010      248.0        9.0       V9329        244.0
# 10  1986     V5010      256.0        9.0       V9329        252.0
# 11  1987     V5010      248.0        9.0       V9329        244.0
# ...
